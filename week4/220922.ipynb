# %% [markdown]
# <a href="https://colab.research.google.com/github/Nahaeran/ai-for-ml-exercise/blob/main/week4/220922.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02
# Out:
# /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_02

# %% [markdown]
# # **Task1**
# <hr>

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('data/earthquakes.csv')

# %%
df.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...     ,ci,  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...     ,ci,  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...     ,nc,  automatic
#
# ...

# %%
df.loc[3:10,['mag','magType','type']]
# Out:
#      mag magType        type
# 3   0.44      ml  earthquake
# 4   2.16      md  earthquake
# 5   2.61      md  earthquake
# 6   1.70      ml  earthquake
# 7   1.13      md  earthquake
# 8   0.92      md  earthquake
# 9   4.70      mb  earthquake
# 10  0.50      ml  earthquake

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %%
df.iloc[3:10,[8,9,21]]
# Out:
#     mag magType        type
# 3  0.44      ml  earthquake
# 4  2.16      md  earthquake
# 5  2.61      md  earthquake
# 6  1.70      ml  earthquake
# 7  1.13      md  earthquake
# 8  0.92      md  earthquake
# 9  4.70      mb  earthquake

# %%
df.loc[
    df.place.str.contains(r'Arizona$'),
    ['alert', 'mag', 'magType', 'title', 'tsunami', 'type']
]
# Out:
#      alert   mag magType                                      title  tsunami  \
# 1062   NaN  1.23      ml  M 1.2 - 7km SSW of Colorado City, Arizona        0
# 3965   NaN  0.94      md  M 0.9 - 7km WSW of Colorado City, Arizona        0
#
#             type
# 1062  earthquake
# 3965  earthquake

# %%
df.mag.sort_values(ascending=False)[:10]
# Out:
# 5263    7.5
# 837     7.0
# 4363    6.7
# 118     6.7
# 799     6.5
# 816     6.2
# 838     6.1
# 5323    6.1
# 9211    6.0
# 862     6.0
# Name: mag, dtype: float64

# %% [markdown]
# # **Task2**
# <hr>

# %%
del df['alert']
df.columns
# Out:
# Index(['cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag', 'magType',
#        'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time',
#        'title', 'tsunami', 'type', 'types', 'tz', 'updated', 'url'],
#       dtype='object')

# %%
magColumn = df.pop('mag')
magColumn.head()
# Out:
# 0    1.35
# 1    1.29
# 2    3.42
# 3    0.44
# 4    2.16
# Name: mag, dtype: float64

# %%
magTypeColumn = df.pop('magType')
magTypeColumn.head()
# Out:
# 0    ml
# 1    ml
# 2    ml
# 3    ml
# 4    md
# Name: magType, dtype: object

# %%
df2 = pd.concat([magColumn, magTypeColumn], axis=1)
df2.head()
# Out:
#     mag magType
# 0  1.35      ml
# 1  1.29      ml
# 2  3.42      ml
# 3  0.44      ml
# 4  2.16      md
